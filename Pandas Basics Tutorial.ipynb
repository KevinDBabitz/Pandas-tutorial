# %%
# import pandas package
import pandas as pd

# %%
# read the airbnb NYC listings csv file
airbnb = pd.read_csv("listings.csv")

# %%
# display the pandas DataFrame 
display(airbnb)
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5178                   Large Furnished Room Near B'way　       8967
# 4          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 37007  48033101  Cozy One-Bedroom with Full Kitchen Near Manhattan  251455701
# 37008  48033611                                Grand Concourse Gem  287782529
# 37009  48038944       Natural Light-Filled Home in Upper East Side  305240193
# 37010  48039640    Spacious Living in the Heart of Upper East Side  305240193
# 37011  48039776   Find Cozy in this Upper West Side Furnished Home  305240193
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 0         Jennifer           Manhattan             Midtown  40.75362
# 1      LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3         Shunichi           Manhattan             Midtown  40.76468
# 4        MaryEllen           Manhattan     Upper West Side  40.80178
# ...            ...                 ...                 ...       ...
# 37007    Alexander              Queens            Woodside  40.74415
# 37008      Adriana               Bronx             Norwood  40.87575
# 37009         June           Manhattan             Midtown  40.75774
# 37010         June           Manhattan     Upper East Side  40.76242
# 37011         June           Manhattan     Upper West Side  40.79850
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.98377  Entire home/apt    100              30                 48
# 1      -73.95976  Entire home/apt     73               1                386
# 2      -73.95596     Private room     60              30                 50
# 3      -73.98315     Private room     79               2                474
# 4      -73.96723     Private room     75               2                118
# ...          ...              ...    ...             ...                ...
# 37007  -73.90941  Entire home/apt     90               3                  0
# 37008  -73.88399     Private room    520               1                  0
# 37009  -73.96173     Private room     63              30                  0
# 37010  -73.95966     Private room     67              30                  0
# 37011  -73.96216     Private room     66              30                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0       11/4/2019               0.35                               2
# 1       1/27/2021               4.99                               1
# 2       12/2/2019               0.35                               1
# 3       9/25/2020               3.31                               1
# 4       7/21/2017               0.85                               1
# ...           ...                ...                             ...
# 37007         NaN                NaN                               2
# 37008         NaN                NaN                               1
# 37009         NaN                NaN                             181
# 37010         NaN                NaN                             181
# 37011         NaN                NaN                             181
#
#        availability_365
# 0                   365
# 1                   249
# 2                   365
# 3                   343
# 4                     0
# ...                 ...
# 37007               365
# 37008               292
# 37009                 1
# 37010               360
# 37011               353
#
# [37012 rows x 16 columns]

# %%
airbnb.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5178                   Large Furnished Room Near B'way　     8967
# 4  5203                 Cozy Clean Guest Room - Family Apt     7490
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3     Shunichi           Manhattan             Midtown  40.76468  -73.98315
# 4    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    100              30                 48   11/4/2019
# 1  Entire home/apt     73               1                386   1/27/2021
# 2     Private room     60              30                 50   12/2/2019
# 3     Private room     79               2                474   9/25/2020
# 4     Private room     75               2                118   7/21/2017
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.35                               2               365
# 1               4.99                               1               249
# 2               0.35                               1               365
# 3               3.31                               1               343
# 4               0.85                               1                 0

# %%
airbnb.tail()
# Out:
#              id                                               name    host_id  \
# 37007  48033101  Cozy One-Bedroom with Full Kitchen Near Manhattan  251455701
# 37008  48033611                                Grand Concourse Gem  287782529
# 37009  48038944       Natural Light-Filled Home in Upper East Side  305240193
# 37010  48039640    Spacious Living in the Heart of Upper East Side  305240193
# 37011  48039776   Find Cozy in this Upper West Side Furnished Home  305240193
#
#        host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 37007  Alexander              Queens         Woodside  40.74415  -73.90941
# 37008    Adriana               Bronx          Norwood  40.87575  -73.88399
# 37009       June           Manhattan          Midtown  40.75774  -73.96173
# 37010       June           Manhattan  Upper East Side  40.76242  -73.95966
# 37011       June           Manhattan  Upper West Side  40.79850  -73.96216
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 37007  Entire home/apt     90               3                  0         NaN
# 37008     Private room    520               1                  0         NaN
# 37009     Private room     63              30                  0         NaN
# 37010     Private room     67              30                  0         NaN
# 37011     Private room     66              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 37007                NaN                               2               365
# 37008                NaN                               1               292
# 37009                NaN                             181                 1
# 37010                NaN                             181               360
# 37011                NaN                             181               353

# %%
# Results for a single column
airbnb['name']
# Out:
# 0                                    Skylit Midtown Castle
# 1        Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                          BlissArtsSpace!
# 3                         Large Furnished Room Near B'way
# 4                       Cozy Clean Guest Room - Family Apt
#                                ...
# 37007    Cozy One-Bedroom with Full Kitchen Near Manhattan
# 37008                                  Grand Concourse Gem
# 37009         Natural Light-Filled Home in Upper East Side
# 37010      Spacious Living in the Heart of Upper East Side
# 37011     Find Cozy in this Upper West Side Furnished Home
# Name: name, Length: 37012, dtype: object

# %%
# results for multiple columns
hosts = airbnb[['host_id', 'host_name']]
hosts.head()
# Out:
#    host_id    host_name
# 0     2845     Jennifer
# 1     4869  LisaRoxanne
# 2     7356        Garon
# 3     8967     Shunichi
# 4     7490    MaryEllen

# %%
# Show the data types for each column
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Change the type of a column to datetime
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
airbnb.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
# extract the year from a datetime series
airbnb['year'] = airbnb['last_review'].dt.year
airbnb['year'].head()
# Out:
# 0    2019.0
# 1    2021.0
# 2    2019.0
# 3    2020.0
# 4    2017.0
# Name: year, dtype: float64

# %%
# Strip leading and trailing spaces from a string series
airbnb['name'] = airbnb['name'].str.strip()
airbnb['name'].head()
# Out:
# 0                                Skylit Midtown Castle
# 1    Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                      BlissArtsSpace!
# 3                      Large Furnished Room Near B'way
# 4                   Cozy Clean Guest Room - Family Apt
# Name: name, dtype: object

# %%
# lowercase all strings in a series
airbnb['name_lower'] = airbnb['name'].str.lower()
airbnb['name_lower'].head()
# Out:
# 0                                skylit midtown castle
# 1    whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                      blissartsspace!
# 3                      large furnished room near b'way
# 4                   cozy clean guest room - family apt
# Name: name_lower, dtype: object

# %%
# calculate using two columns
airbnb['min_revenue'] = airbnb['minimum_nights'] * airbnb['price']
airbnb[['minimum_nights', 'price', 'min_revenue']].head()
# Out:
#    minimum_nights  price  min_revenue
# 0              30    100         3000
# 1               1     73           73
# 2              30     60         1800
# 3               2     79          158
# 4               2     75          150

# %%
# get the mean price
airbnb['price'].mean()
# Out:
# 142.84224035447963

# %%
# get the median price
airbnb['price'].median()
# Out:
# 99.0

# %%
# get the mean grouped by type of room
airbnb[['room_type', 'price']].groupby('room_type', as_index=False).mean()
# Out:
#          room_type       price
# 0  Entire home/apt  191.461308
# 1       Hotel room  228.568562
# 2     Private room   86.318701
# 3      Shared room  100.991254

# %%
# get the median grouped by type of room
airbnb[['room_type', 'price']].groupby('room_type', as_index=False).median()
# Out:
#          room_type  price
# 0  Entire home/apt    140
# 1       Hotel room    150
# 2     Private room     60
# 3      Shared room     45

# %%
# get the median grouped by type of room and year
airbnb[['room_type', 'year', 'price']].groupby(['room_type', 'year'], as_index=False).median()
# Out:
#           room_type    year  price
# 0   Entire home/apt  2010.0   99.0
# 1   Entire home/apt  2011.0  199.5
# 2   Entire home/apt  2012.0  125.0
# 3   Entire home/apt  2013.0  150.0
# 4   Entire home/apt  2014.0  173.0
# 5   Entire home/apt  2015.0  150.0
# 6   Entire home/apt  2016.0  150.0
# 7   Entire home/apt  2017.0  149.0
# 8   Entire home/apt  2018.0  150.0
# 9   Entire home/apt  2019.0  150.0
# 10  Entire home/apt  2020.0  130.0
# 11  Entire home/apt  2021.0  112.0
# 12       Hotel room  2016.0  349.0
# 13       Hotel room  2017.0  248.0
# 14       Hotel room  2018.0  100.0
# 15       Hotel room  2019.0  229.0
# 16       Hotel room  2020.0  142.0
# 17       Hotel room  2021.0  108.5
# 18     Private room  2011.0  249.0
# 19     Private room  2012.0  164.0
# 20     Private room  2013.0   85.0
# 21     Private room  2014.0   75.0
# 22     Private room  2015.0   75.0
# 23     Private room  2016.0   65.0
# 24     Private room  2017.0   65.0
# 25     Private room  2018.0   65.0
# 26     Private room  2019.0   69.0
# 27     Private room  2020.0   60.0
# 28     Private room  2021.0   50.0
# 29      Shared room  2014.0   84.0
# 30      Shared room  2015.0   57.5
# 31      Shared room  2016.0   97.0
# 32      Shared room  2017.0   70.0
# 33      Shared room  2018.0   42.0
# 34      Shared room  2019.0   50.0
# 35      Shared room  2020.0   39.0
# 36      Shared room  2021.0   31.5

# %%
# get all rows with price < 1000
airbnb_under_1000 = airbnb[airbnb['price'] < 1000]
airbnb_under_1000.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5178                    Large Furnished Room Near B'way     8967
# 4  5203                 Cozy Clean Guest Room - Family Apt     7490
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3     Shunichi           Manhattan             Midtown  40.76468  -73.98315
# 4    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    100              30                 48  2019-11-04
# 1  Entire home/apt     73               1                386  2021-01-27
# 2     Private room     60              30                 50  2019-12-02
# 3     Private room     79               2                474  2020-09-25
# 4     Private room     75               2                118  2017-07-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.35                               2               365
# 1               4.99                               1               249
# 2               0.35                               1               365
# 3               3.31                               1               343
# 4               0.85                               1                 0
#
#      year                                         name_lower  min_revenue
# 0  2019.0                              skylit midtown castle         3000
# 1  2021.0  whole flr w/private bdrm, bath & kitchen(pls r...           73
# 2  2019.0                                    blissartsspace!         1800
# 3  2020.0                    large furnished room near b'way          158
# 4  2017.0                 cozy clean guest room - family apt          150

# %%
# get all rows with price < 1000 and year equal to 2020
airbnb_2019_under_1000 = airbnb[(airbnb['price'] < 1000) & (airbnb['year'] == 2020)]
airbnb_2019_under_1000.head()
# Out:
#       id                                            name  host_id  \
# 3   5178                 Large Furnished Room Near B'way     8967
# 5   5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 6   6848                Only 2 stops to Manhattan studio    15991
# 14  9657                Modern 1 BR / NYC / East Village    21904
# 15  9704             Spacious 1 bedroom in luxe building    32045
#
#         host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 3        Shunichi           Manhattan       Midtown  40.76468  -73.98315
# 5          Laurie            Brooklyn   South Slope  40.66829  -73.98779
# 6   Allen & Irina            Brooklyn  Williamsburg  40.70837  -73.95352
# 14           Dana           Manhattan  East Village  40.72920  -73.98542
# 15           Teri           Manhattan        Harlem  40.81305  -73.95466
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 3      Private room     79               2                474  2020-09-25
# 5      Private room     83               4                182  2020-10-17
# 6   Entire home/apt    109              30                181  2020-03-16
# 14  Entire home/apt    150              10                 35  2020-11-06
# 15     Private room     55              30                 98  2020-03-14
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 3                3.31                               1               343
# 5                1.27                               3               365
# 6                1.27                               1               309
# 14               0.25                               1                74
# 15               1.21                               1               365
#
#       year                                      name_lower  min_revenue
# 3   2020.0                 large furnished room near b'way          158
# 5   2020.0  lovely room 1, garden, best area, legal rental          332
# 6   2020.0                only 2 stops to manhattan studio         3270
# 14  2020.0                modern 1 br / nyc / east village         1500
# 15  2020.0             spacious 1 bedroom in luxe building         1650

# %%
# distribution of prices under $1000 
ax = airbnb_under_1000['price'].plot.hist(bins=40)
